# %% [markdown]
# # Clustering Toronto Destinations Report
# An Applied Data Science Capstone Project
# by Morales, J. 2020

# %% [markdown]
# ## 1. Introduction
# In the introduction section, we discuss the business problem and background and stakeholders who will be interested in the project.
#
# ### 1.1. Problem description and background
# Planning a trip to a foreign city can be daunting. Often equipped with limited budget, time, and experience in of the foreign city, visitors want to make the most of their stay. But how? This is where I would like to help. Using data science, the Toronto neighbourhoods dataset, and FourSquare, I would like to answer the following questions.
#
# - Which neighbourhoods are teeming with Toronto destinations for visitors?
# - Which neighbourhoods offer the most diverse experiences for Toronto visitors?
#
#
# ### 1.2. Who would be interested?
# There are a variety of folks who can benefit from this project including Toronto visitors, city tour guides, and foreign travel agencies.
#
# - Toronto visitors who are planning their trip would be interested to see what destinations are closest to their place of accommodation.
#
# - Torontonians playing tour guide for visiting family, friends, or acquaintances.
#
# - Tour guides giving city-round tours.
#
# - Travel agencies or consultants giving suggestions to clients.

# %% [markdown]
# ## 2. About the data
# In the data section, we discuss the data that will be used to solve the problem.
#
# ### 2.1. Toronto dataset
# - It has  information such as Toronto postal codes, boroughs, neighbourhoods.
# - I used it to glean information about the neighbourhoods.
# - The source is Wikipedia. I used webscraping to obtain the information. The data was then cleansed and amalgamated with the other datasets.
#
# ### 2.2. Geocodes
# - It will have information about geo coordinates, i.e., latitude and longtitude.
# - I will use it to glean information about the geo coordinates of the neighbourhoods so that I can get the venues from Foursquare.
# - The source is the Applied Data Science Capstone Course week 3 learning materials. The data was then amalgamated with the other datasets.
#
# ### 2.3.Venues
# - It will have information from Foursquare about different venues in the city of Toronto including the types of venues, reviews, and so on.
# - I will use it to glean information about the venues in different Toronto neighbourhoods.
# - The source is Foursquare. I built an app that connected to Frousquare to pull this information. The data was then cleansed and amalgamated with the other datasets.

# %% [markdown]
# ## 3. Methodology
# In the methodology section, we discuss and describe the exploratory data analysis done, any inferential statistical testing performed, and machine learning models used and why.
#
# ### 3.1. Data preparation
# Data preparation involved scraping neighbourhoods with postal codes starting with 'M'. This entailed neighbourhoods in Toronto. Boroughs with values 'Not Assigned' were imputed by aggergating these cases with neighbourhoods, whose values were not missing, using identical postal codes.
# The prepared Toronto dataset was combined with geospatial coordinates dataset containing latitudes and longitudes.
#
# ### 3.2. Exploratory data analysis
# Data was visually explored by creating a map of Toronto and superimposing the neighbourhoods on top of the map.
# Data was further explored by slicing the dataset and obtaining only boroughts with the string 'Toronto', leading us to focus on the downtown-ish areas.
# Simple clustering was also applied to divide these neighbourhoods into areas.
#
# ### 3.3. More data preparation and exploration
# The venues information was obtained from Foursquare and combined with the sliced datset of Toronto neighbourhoods. Now we are working with Toronto neighbourhoods in the downtown area with knowledge of the venues in those neighbourhoods.
# Initial exploration showed a total of 1729 cases.
#
# ### 3.4. Machine learning techniques
# Clustering was applied throughout the process. Clustering helps us see similarities of elements within a cluster and dissimilarities of elements across cluster. It is also intuitive when used in conjunction with Folium / mapping.

# %% [markdown]
# ## 4. Results
# In the results section, we discuss the results of the project.
#
# ### 4.1. Preliminary observations
# There are about 1103 unique venues in the downtown area of Toronto.
# There are about 236 unique venue categories in the downtown area of Toronto.
#
# ### 4.2. Highlights: destinations with the greatest number of venues
# There were at least seven neighbourhoods with at least 100 venues in the downtown area of Toronto.
# The top 10 neighbourhoods are:
# ![image1.png](attachment:image.png)

# %% [markdown]
# ### 4.3. Highlights: destinations with the most diverse venues
# There were at least nine neighbourhoods with at least 52 types of venues in the downtown area of Toronto.
# The top 10 neighbourhoods are:
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5. Discussion
# In the discussion section, we discuss the observations noted during the exercise and recommendations based on the results of the project.
#
# ### 5.1. Which neighbourhoods are teeming with Toronto destinations for visitors?
# The downtown area of Toronto is teeming with destinations for visitors. If anyone is looking to experience or see as many venues as possible, the top 10 neighbourhoods are safe choices. Teeming neighbourhoods are not limited to the top 10, a majority of the neighbourhoods in the downtown area are filled with venues.
#
#
# ### 5.2. Which neighbourhoods offer the most diverse experiences for Toronto visitors?
# Toronto is a very diverse city. The types of venues you will find in the downtown area are equally diverse. If anyone is looking to experience or see as many diverse venues as possible, the top 10 neighbourhoods are safe choices. Diverse neighbourhoods are not limited to the top 10, a majority of the neighbourhoods in the downtown area are filled with venues.

# %% [markdown]
# ## 6. Conclusion
# In the conclusion section, we conclude by summarising the project experience.
#
# In this project, we introduced the problem, background, benefits to visitors and similar persons of finding the greatest number of destinations or venues in the downtown area of Toronto and the most diverse destinations or venues in the area. By applying simple techniques and amalgamating disparate datasets, we were able to answer these questions.
#
# Thank you for reading.

# %% [markdown]
# ## Appendices
#
# Clustering Toronto Destinations - Project Report
#
# https://github.com/jamiemorales/project-clustering-toronto-destinations/blob/master/clustering-toronto-destinations-report.ipynb
#
#
#
# Clustering Toronto Destinations - Project Code
#
# https://github.com/jamiemorales/project-clustering-toronto-destinations/blob/master/clustering-toronto-destinations-code.ipynb
#
#
#
# Clustering Toronto Destinations - Project Abstract
#
# https://github.com/jamiemorales/project-clustering-toronto-destinations/blob/master/clustering-toronto-destinations-abstract.ipynb
#
#
#
# Clustering Toronto Destinations - Project Presentation
#
# https://github.com/jamiemorales/project-clustering-toronto-destinations/blob/master/clustering-toronto-destinations-presentation.ipynb
#
#
#
#
# Clustering Toronto Destinations - Project Repo
#
# https://github.com/jamiemorales/project-clustering-toronto-destinations

# %% [markdown]
# --------------------------------------------------------------------------------
# Please cite if you use or share the content(s)/repo.
#
# How to cite: Morales, J. 2020 Clustering Toronto Destinations Report
#
# License: https://creativecommons.org/licenses/by-sa/4.0/
